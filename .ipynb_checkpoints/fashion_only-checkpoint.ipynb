# %%
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
import load_mnist
import time

# %%
tf.__version__
# Out:
# '1.9.0'

# %%
from cnn_model import model

# %%
def reshape_image(x):
    x = np.transpose(x,[0,2,3,1])
    return x

# %%
mnist = dict()
mnist['train_x'],mnist['train_y'],mnist['test_x'],mnist['test_y'] = load_mnist.load_mnist_dataset(os.getcwd()+"/fashion")
mnist['train_x'].shape,mnist['test_x'].shape
# Out:
# ((60000, 1, 28, 28), (10000, 1, 28, 28))

# %%
mnist['train_x'] = reshape_image(mnist['train_x'])
mnist['test_x'] = reshape_image(mnist['test_x'])

# %%
mnist['train_x'].shape,mnist['test_x'].shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
batch_size = 100

# %%
#train
dtrain_x = tf.data.Dataset.from_tensor_slices(mnist['train_x'])
dtrain_y = tf.data.Dataset.from_tensor_slices(mnist['train_y']).map(lambda x: tf.one_hot(x,10))
train_data = tf.data.Dataset.zip((dtrain_x,dtrain_y)).shuffle(1000).repeat().batch(batch_size)

dtest_x = tf.data.Dataset.from_tensor_slices(mnist['test_x'])
dtest_y = tf.data.Dataset.from_tensor_slices(mnist['test_y']).map(lambda x: tf.one_hot(x,10))
test_data = tf.data.Dataset.zip((dtest_x,dtest_y)).batch(batch_size)

dvalid_x = tf.data.Dataset.from_tensor_slices(mnist['test_x'][:1001])
dvalid_y = tf.data.Dataset.from_tensor_slices(mnist['test_y'][:1001]).map(lambda x: tf.one_hot(x,10))
valid_data =  tf.data.Dataset.zip((dvalid_x,dvalid_y)).repeat().batch(batch_size)

(train_data,test_data,valid_data)
# Out:
# (<BatchDataset shapes: ((?, 28, 28, 1), (?, 10)), types: (tf.float32, tf.float32)>,
#  <BatchDataset shapes: ((?, 28, 28, 1), (?, 10)), types: (tf.float32, tf.float32)>,
#  <BatchDataset shapes: ((?, 28, 28, 1), (?, 10)), types: (tf.float32, tf.float32)>)

# %%
# data pipline iterator initializer
iterator = tf.data.Iterator.from_structure(train_data.output_types,train_data.output_shapes)
get_batch = iterator.get_next()

#train data initiallizer shuffled
train_init = iterator.make_initializer(train_data)
#test data initializer shuffled
test_init = iterator.make_initializer(test_data)
# test data one shot initializer
valid_init = iterator.make_initializer(valid_data)

# %%
param=[]
param.append(1)
param.append([5,64])
param.append([5,64])
param.append(1500)
param.append(10)
len(param)
# Out:
# 5

# %%
is_train = tf.placeholder(shape=(),dtype=tf.bool)
prob_keep = tf.placeholder(shape=(),dtype=tf.float32)
cnn = model(get_batch[0],is_train,prob_keep,param)

# %%
logits = cnn.logits
cnn.total_params()
# Out:
# <tf.Tensor 'dense_1/BiasAdd:0' shape=(?, 10) dtype=float32>

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=get_batch[1],logits=logits))

tf.summary.scalar("losses",loss)
optimizer = tf.train.AdamOptimizer(0.001).minimize(loss)

#get accuracy
predictions = tf.argmax(logits,axis=1)
equality = tf.equal(predictions,tf.argmax(get_batch[1],axis=1))
accuracy = tf.reduce_mean(tf.cast(equality,tf.float32))
tf.summary.scalar("accuracy",accuracy)
init_op = tf.global_variables_initializer()

# %%
log_dir = '/output/logs_fashion'
print(log_dir)
t_summary = tf.summary.merge_all()
writer = tf.summary.FileWriter(log_dir)
saver = tf.train.Saver()
# Out:
# C:\Users\k_tej\Documents\TEJA\ML_resources\clg_project\Model\logs_mnist

# %%
epochs = int(120000/(2*100))
probability_keep = 0.5
# Out:
# 600

# %%
duration = 0
with tf.Session() as sess:
    #saver.restore(sess,log_dir+'/curr_model.ckpt')
    writer.add_graph(sess.graph)
    sess.run(init_op)
    sess.run(train_init)
    train_log_loss=[]
    valid_log_acc =[]
    for i in range(1,epochs+1):
        
        start_time = time.time()
        l,_,acc,s = sess.run([loss,optimizer,accuracy,t_summary],feed_dict={is_train:True,prob_keep:probability_keep})
        duration = duration + time.time() - start_time
        
        writer.add_summary(s,i)
        # history of loss and accuracy while training
        train_log_loss.append(l)
        
        if i%100==0:
            print("Epoch :{}, loss :{:.3f}, accuracy :{:.3f}".format(i,l,acc))
            save_path = saver.save(sess,log_dir+'/curr_model.ckpt')
            
        valid_iter = 10
        avg_acc = 0
        sess.run(valid_init)
        for _ in range(valid_iter):
            acc = sess.run([accuracy],feed_dict = {is_train:False,prob_keep:1.0})
            avg_acc+=acc[0]
        avg_acc=avg_acc*100.0/10
        valid_log_acc.append(avg_acc)
        print("average accuracy :{:.2f}".format(avg_acc))
        
    
    
    print("total training duration : {} sec".format(duration))
    #final accuracy on test data
    i=0
    test_acc = 0
    sess.run(test_init)
    while True:
        try:
            i+=1
            #100 --> batch size for one_shot_iter is 100
            acc = sess.run([accuracy],feed_dict = {is_train:False,prob_keep:1.0})
            test_acc+=acc[0]
        except tf.errors.OutOfRangeError:
            print("number of iter  : {}".format(i))
            print("Test Accuracy: {}".format(test_acc/100))
            plt.plot(train_log_loss,label='loss_train',color='r')
            plt.plot(valid_log_acc,label='acc_train',color='b')
            plt.xlabel("epochs")
            plt.legend()
            plt.show()
            break
# Out:
# Epoch :0, loss :395.766, accuracy :0.110
# average accuracy :17.40
# average accuracy :33.10
# average accuracy :42.20
# average accuracy :50.30
# average accuracy :43.30
# average accuracy :44.70
# average accuracy :58.10
# average accuracy :54.40
# average accuracy :55.50
# average accuracy :60.00
# average accuracy :64.40
# average accuracy :66.60
# average accuracy :70.80
# average accuracy :67.90
# average accuracy :65.10
# average accuracy :63.80
# average accuracy :64.70
# average accuracy :65.80
# average accuracy :67.10
# average accuracy :70.20
# average accuracy :72.00
# average accuracy :71.90
# average accuracy :73.40
# average accuracy :73.10
# average accuracy :72.90
# average accuracy :72.70
# average accuracy :72.20
# average accuracy :72.40
# average accuracy :73.50
# average accuracy :74.00
# average accuracy :74.40
# average accuracy :75.30
# average accuracy :75.70
# average accuracy :76.00
# average accuracy :76.20
# average accuracy :76.20
# average accuracy :76.40
# average accuracy :76.60
# average accuracy :76.80
# average accuracy :77.00
# average accuracy :76.80
# average accuracy :76.70
# average accuracy :76.60
# average accuracy :76.60
# average accuracy :76.50
# average accuracy :76.60
# average accuracy :76.80
# average accuracy :76.60
# average accuracy :76.60
# average accuracy :76.40
# average accuracy :76.60
# average accuracy :76.70
# average accuracy :76.90
# average accuracy :77.00
# average accuracy :76.90
# average accuracy :76.90
# average accuracy :76.90
# average accuracy :77.00
# average accuracy :76.90
# average accuracy :77.00
# average accuracy :77.10
# average accuracy :77.10
# average accuracy :77.10
# average accuracy :77.00
# average accuracy :77.10
# average accuracy :77.00
# average accuracy :77.00
# average accuracy :77.00
# average accuracy :77.00
# average accuracy :77.00
# average accuracy :77.20
# average accuracy :77.10
# average accuracy :77.20
# average accuracy :77.20
# average accuracy :77.30
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.50
# average accuracy :77.70
# average accuracy :77.60
# average accuracy :77.60
# average accuracy :77.60
# average accuracy :77.60
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.10
# average accuracy :77.30
# average accuracy :77.10
# average accuracy :77.20
# average accuracy :77.10
# average accuracy :77.10
# average accuracy :77.10
# average accuracy :77.50
# Epoch :100, loss :0.000, accuracy :1.000
# average accuracy :77.40
# average accuracy :77.30
# average accuracy :77.40
# average accuracy :77.30
# average accuracy :77.40
# average accuracy :77.10
# average accuracy :77.20
# average accuracy :77.20
# average accuracy :77.20
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.80
# average accuracy :77.80
# average accuracy :78.00
# average accuracy :78.20
# average accuracy :78.30
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.30
# average accuracy :78.60
# average accuracy :78.50
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.70
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.60
# average accuracy :78.10
# average accuracy :78.10
# average accuracy :78.20
# average accuracy :78.10
# average accuracy :78.10
# average accuracy :78.00
# average accuracy :77.80
# average accuracy :77.80
# average accuracy :77.70
# average accuracy :77.70
# average accuracy :77.70
# average accuracy :77.70
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.20
# average accuracy :77.30
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.60
# average accuracy :77.70
# average accuracy :77.70
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.40
# average accuracy :77.40
# average accuracy :77.50
# average accuracy :77.20
# average accuracy :77.30
# average accuracy :77.40
# average accuracy :77.50
# average accuracy :77.50
# average accuracy :77.80
# average accuracy :78.00
# average accuracy :78.10
# average accuracy :78.60
# average accuracy :78.80
# average accuracy :79.20
# average accuracy :79.30
# average accuracy :79.30
# average accuracy :79.10
# average accuracy :78.90
# average accuracy :78.80
# average accuracy :78.70
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.80
# average accuracy :78.90
# average accuracy :78.80
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.70
# average accuracy :78.60
# average accuracy :78.50
# average accuracy :78.60
# average accuracy :78.50
# Epoch :200, loss :0.000, accuracy :1.000
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.30
# average accuracy :78.40
# average accuracy :78.60
# average accuracy :78.50
# average accuracy :78.60
# average accuracy :78.70
# average accuracy :78.70
# average accuracy :78.80
# average accuracy :78.80
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :78.90
# average accuracy :78.80
# average accuracy :78.80
# average accuracy :78.80
# average accuracy :78.70
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.60
# average accuracy :78.50
# average accuracy :78.30
# average accuracy :78.00
# average accuracy :78.10
# average accuracy :78.00
# average accuracy :78.00
# average accuracy :78.20
# average accuracy :78.10
# average accuracy :78.20
# average accuracy :78.30
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.00
# average accuracy :78.00
# average accuracy :78.00
# average accuracy :78.40
# average accuracy :78.20
# average accuracy :78.20
# average accuracy :78.30
# average accuracy :78.20
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.40
# Epoch :300, loss :0.000, accuracy :1.000
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.40
# average accuracy :78.50
# average accuracy :78.50
# average accuracy :78.80
# average accuracy :78.80
# average accuracy :79.00
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.00
# average accuracy :78.90
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.30
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :78.90
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# Epoch :400, loss :0.000, accuracy :1.000
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# Epoch :500, loss :0.000, accuracy :1.000
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :78.90
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.20
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.00
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# average accuracy :79.10
# total training duration : 1710.3955988883972 sec
# number of iter  : 91
# Test Accuracy: 0.757838386297226

# %%
t_acc = 0
with tf.Session() as sess:
    saver.restore(sess,log_dir+'/curr_model.ckpt')
    sess.run(train_init)
    for i in range(600):
        acc = sess.run([accuracy],feed_dict = {is_train:False,prob_keep:1.0})
        t_acc+=acc[0]
    print(t_acc*100/600)
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\k_tej\Documents\TEJA\ML_resources\clg_project\Model\logs_mnist/curr_model.ckpt
# 85.93924254179001

# %%
mnist_dict = dict()
mnist_dict['duration'] = np.array([duration])
mnist_dict['loss'] = np.array(train_log_loss)
mnist_dict['accuracy'] = np.array(valid_log_acc)
mnist_dict['test_accuracy'] = np.array(test_acc)
mnist_dict['train_accuracy'] = np.array(t_acc)
np.save('fashion_logs_saves.npy',mnist_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7aaacb47ea58> in <module>()
#       1 mnist_dict = dict()
# ----> 2 mnist_dict['duration'] = np.array([duration])
#       3 mnist_dict['loss'] = np.array(train_log_loss)
#       4 mnist_dict['accuracy'] = np.array(valid_log_acc)
#       5 mnist_dict['test_accuracy'] = np.array(test_acc)
#
# NameError: name 'np' is not defined
